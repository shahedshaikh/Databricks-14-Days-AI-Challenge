# %%
import pandas as pd 
df=pd.read_csv("https://raw.githubusercontent.com/Drushti2706/Ecommerce-sales-dataset/refs/heads/main/ecommerce_sales_data.csv")

# %%
events = spark.createDataFrame(df)

events.show(5)
events.printSchema()
# Out:
# +--------+-----------+------+---+----------------+------------+--------+-------+----------+----------------+---------+------+
# |Order ID|Customer ID|Gender|Age|Product Category|Product Name|Quantity|  Price|Order Date|  Payment Method|     City|Rating|
# +--------+-----------+------+---+----------------+------------+--------+-------+----------+----------------+---------+------+
# | ORD0001|   CUST9376|Female| 43|            Home|        Lamp|       1|1368.69|07-06-2025|Cash on Delivery|Hyderabad|     3|
# | ORD0002|   CUST3289|  Male| 57|            Toys|    Lego Set|       5| 782.44|11-12-2024|Cash on Delivery|  Chennai|     5|
# | ORD0003|   CUST6409|Female| 53|        Clothing|      Jacket|       1|3676.18|05-05-2025|     Credit Card|Bangalore|     4|
# | ORD0004|   CUST8815|Female| 51|          Beauty|     Perfume|       2|4836.37|25-06-2025|Cash on Delivery|   Mumbai|     5|
# | ORD0005|   CUST1018|Female| 39|     Electronics|  Smartphone|       4|3580.24|25-12-2024|             UPI|  Kolkata|     3|
# +--------+-----------+------+---+----------------+------------+--------+-------+----------+----------------+---------+------+
# only showing top 5 rows
# root
#  |-- Order ID: string (nullable = true)
#  |-- Customer ID: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Age: long (nullable = true)
#  |-- Product Category: string (nullable = true)
#  |-- Product Name: string (nullable = true)
#  |-- Quantity: long (nullable = true)
#  |-- Price: double (nullable = true)
#  |-- Order Date: string (nullable = true)
#  |-- Payment Method: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Rating: long (nullable = true)

# %% [markdown]
# Select Columns

# %%
events.select(
    "Order ID",
    "Product Category",
    "Product Name",
    "Quantity",
    "Price",
    "City"
).show(10)
# Out:
# +--------+----------------+-------------+--------+-------+---------+
# |Order ID|Product Category| Product Name|Quantity|  Price|     City|
# +--------+----------------+-------------+--------+-------+---------+
# | ORD0001|            Home|         Lamp|       1|1368.69|Hyderabad|
# | ORD0002|            Toys|     Lego Set|       5| 782.44|  Chennai|
# | ORD0003|        Clothing|       Jacket|       1|3676.18|Bangalore|
# | ORD0004|          Beauty|      Perfume|       2|4836.37|   Mumbai|
# | ORD0005|     Electronics|   Smartphone|       4|3580.24|  Kolkata|
# | ORD0006|           Books|      Fiction|       2|4593.39|   Mumbai|
# | ORD0007|          Beauty|      Perfume|       4| 634.38|  Chennai|
# | ORD0008|            Toys|Action Figure|       5|1509.52|Bangalore|
# | ORD0009|        Clothing|        Jeans|       1|3102.59|  Kolkata|
# | ORD0010|        Clothing|      T-Shirt|       1|4501.05|  Chennai|
# +--------+----------------+-------------+--------+-------+---------+
# only showing top 10 rows

# %% [markdown]
# Filter Data

# %%
high_value_orders = events.filter(events["Price"] > 3000)
high_value_orders.count()
# Out:
# 41

# %% [markdown]
# Group By Operations
# Orders by Product Category

# %%
events.groupBy("Product Category").count().show()
# Out:
# +----------------+-----+
# |Product Category|count|
# +----------------+-----+
# |            Home|   17|
# |            Toys|   12|
# |        Clothing|   21|
# |          Beauty|   13|
# |     Electronics|   19|
# |           Books|   18|
# +----------------+-----+

# %% [markdown]
# Total Quantity Sold per Category

# %%
category_sales = (
    events.groupBy("Product Category")
    .sum("Quantity")
    .withColumnRenamed("sum(Quantity)", "Total_Quantity")
)

category_sales.show()
# Out:
# +----------------+--------------+
# |Product Category|Total_Quantity|
# +----------------+--------------+
# |            Home|            51|
# |            Toys|            36|
# |        Clothing|            56|
# |          Beauty|            35|
# |     Electronics|            58|
# |           Books|            58|
# +----------------+--------------+

# %% [markdown]
# Order By (Sorting)

# %%
category_sales.orderBy("Total_Quantity", ascending=False).show()
# Out:
# +----------------+--------------+
# |Product Category|Total_Quantity|
# +----------------+--------------+
# |     Electronics|            58|
# |           Books|            58|
# |        Clothing|            56|
# |            Home|            51|
# |            Toys|            36|
# |          Beauty|            35|
# +----------------+--------------+

# %% [markdown]
# Top N Analysis
#
# Top 5 selling product categories:

# %%
top_5_categories = category_sales.orderBy(
    "Total_Quantity", ascending=False
).limit(5)

top_5_categories.show()
# Out:
# +----------------+--------------+
# |Product Category|Total_Quantity|
# +----------------+--------------+
# |           Books|            58|
# |     Electronics|            58|
# |        Clothing|            56|
# |            Home|            51|
# |            Toys|            36|
# +----------------+--------------+

# %% [markdown]
# Spark SQL vs DataFrame API

# %%
events.createOrReplaceTempView("ecommerce_tbl")

# %%
# %sql
SELECT City,
       COUNT(*) AS total_orders,
       SUM(Quantity * Price) AS total_sales
FROM ecommerce_tbl
GROUP BY City
ORDER BY total_sales DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>City</th><th>total_orders</th><th>total_sales</th></tr></thead><tbody><tr><td>Kolkata</td><td>20</td><td>190462.97999999998</td></tr><tr><td>Hyderabad</td><td>15</td><td>130424.17</td></tr><tr><td>Mumbai</td><td>20</td><td>118183.94999999998</td></tr><tr><td>Chennai</td><td>22</td><td>109181.81</td></tr><tr><td>Bangalore</td><td>14</td><td>90184.49</td></tr><tr><td>Delhi</td><td>9</td><td>55782.469999999994</td></tr></tbody></table></div>

# %% [markdown]
# Lazy Evaluation Demo

# %%
filtered_df = events.filter(events["Rating"] >= 4)
# No execution yet

filtered_df.show()  # Action triggers Spark job
# Out:
# +--------+-----------+------+---+----------------+-------------+--------+-------+----------+----------------+---------+------+
# |Order ID|Customer ID|Gender|Age|Product Category| Product Name|Quantity|  Price|Order Date|  Payment Method|     City|Rating|
# +--------+-----------+------+---+----------------+-------------+--------+-------+----------+----------------+---------+------+
# | ORD0002|   CUST3289|  Male| 57|            Toys|     Lego Set|       5| 782.44|11-12-2024|Cash on Delivery|  Chennai|     5|
# | ORD0003|   CUST6409|Female| 53|        Clothing|       Jacket|       1|3676.18|05-05-2025|     Credit Card|Bangalore|     4|
# | ORD0004|   CUST8815|Female| 51|          Beauty|      Perfume|       2|4836.37|25-06-2025|Cash on Delivery|   Mumbai|     5|
# | ORD0013|   CUST2018|  Male| 27|          Beauty|     Lipstick|       3|2188.04|02-06-2025|             UPI|   Mumbai|     5|
# | ORD0014|   CUST1437|  Male| 58|           Books|       Comics|       5|3434.89|09-11-2024|             UPI|  Chennai|     5|
# | ORD0017|   CUST5932|Female| 45|          Beauty|     Lipstick|       2| 452.66|26-02-2025|             UPI|   Mumbai|     5|
# | ORD0018|   CUST7410|  Male| 34|            Home| Cookware Set|       5| 594.51|26-06-2025|Cash on Delivery|  Kolkata|     4|
# | ORD0022|   CUST6885|  Male| 37|            Home|         Lamp|       5| 1510.6|07-09-2024|      Netbanking|  Kolkata|     4|
# | ORD0023|   CUST6478|  Male| 33|           Books|      Fiction|       1|3013.43|01-11-2024|             UPI|  Kolkata|     4|
# | ORD0025|   CUST3583|Female| 51|        Clothing|        Dress|       1|1370.21|04-05-2025|      Netbanking|  Chennai|     5|
# | ORD0031|   CUST7011|  Male| 56|           Books|    Biography|       5|1642.09|06-02-2025|      Netbanking|  Kolkata|     4|
# | ORD0035|   CUST2161|Female| 43|     Electronics|   Headphones|       2|4299.48|30-06-2025|Cash on Delivery|Bangalore|     4|
# | ORD0038|   CUST2001|Female| 18|     Electronics|   Smartphone|       2|3774.36|22-08-2024|     Credit Card|Hyderabad|     5|
# | ORD0042|   CUST3479|  Male| 56|            Home|         Lamp|       3|2777.32|10-06-2025|      Netbanking|    Delhi|     5|
# | ORD0044|   CUST6214|Female| 20|            Toys|Action Figure|       2| 147.55|20-11-2024|             UPI|Bangalore|     5|
# | ORD0046|   CUST8349|Female| 28|        Clothing|      T-Shirt|       3|  174.9|17-02-2025|             UPI|  Kolkata|     4|
# | ORD0047|   CUST9231|  Male| 54|          Beauty|      Perfume|       4|4515.34|23-08-2024|     Credit Card|  Kolkata|     5|
# | ORD0048|   CUST4376|Female| 52|            Toys|     Lego Set|       4|4538.33|29-11-2024|      Netbanking|Hyderabad|     4|
# | ORD0049|   CUST1335|  Male| 29|            Toys|Action Figure|       2|4271.45|30-12-2024|Cash on Delivery|  Chennai|     5|
# | ORD0052|   CUST3480|Female| 44|            Home|     Curtains|       1|3400.36|20-03-2025|     Credit Card|  Chennai|     4|
# +--------+-----------+------+---+----------------+-------------+--------+-------+----------+----------------+---------+------+
# only showing top 20 rows
