# %%
# %sql
CREATE VOLUME IF NOT EXISTS main.default.raw_data;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW VOLUMES IN main.default;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>volume_name</th></tr></thead><tbody><tr><td>default</td><td>raw_data</td></tr><tr><td>default</td><td>sales_volume</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE VOLUME main.default.raw_data;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>catalog</th><th>database</th><th>owner</th><th>storage_location</th><th>volume_type</th><th>comment</th><th>securable_type</th><th>securable_kind</th></tr></thead><tbody><tr><td>raw_data</td><td>main</td><td>default</td><td>testwest1221@gmail.com</td><td></td><td>MANAGED</td><td>null</td><td>VOLUME</td><td>VOLUME_DB_STORAGE</td></tr></tbody></table></div>

# %%
dbutils.widgets.removeAll()

# %%
dbutils.widgets.text(
    "source_path",
    "/Volumes/main/default/raw_data/sales.csv"
)

dbutils.widgets.text(
    "bronze_table",
    "main.default.bronze_sales"
)

source_path = dbutils.widgets.get("source_path")
bronze_table = dbutils.widgets.get("bronze_table")

df = spark.read.option("header", True).csv(source_path)

df.write.format("delta") \
  .mode("overwrite") \
  .saveAsTable(bronze_table)

print("✅ Bronze layer completed")
# Out:
# ✅ Bronze layer completed

# %%
# %sql
SELECT * FROM main.default.bronze_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>order_id</th><th>customer_id</th><th>category</th><th>price</th><th>quantity</th><th>revenue</th></tr></thead><tbody><tr><td>2023-01-01</td><td>20230101-489713</td><td>8726</td><td>Toys</td><td>63.95</td><td>4</td><td>255.8</td></tr><tr><td>2023-01-01</td><td>20230101-505413</td><td>3044</td><td>Beauty</td><td>27.82</td><td>2</td><td>55.64</td></tr><tr><td>2023-01-01</td><td>20230101-427515</td><td>5200</td><td>Electronics</td><td>80.12</td><td>1</td><td>80.12</td></tr><tr><td>2023-01-01</td><td>20230101-516646</td><td>2169</td><td>Home</td><td>83.68</td><td>3</td><td>251.04</td></tr><tr><td>2023-01-01</td><td>20230101-315601</td><td>7141</td><td>Electronics</td><td>82.78</td><td>2</td><td>165.56</td></tr><tr><td>2023-01-01</td><td>20230101-320932</td><td>2030</td><td>Beauty</td><td>47.07</td><td>1</td><td>47.07</td></tr><tr><td>2023-01-01</td><td>20230101-412748</td><td>4930</td><td>Electronics</td><td>146.22</td><td>4</td><td>584.88</td></tr><tr><td>2023-01-01</td><td>20230101-476162</td><td>8325</td><td>Electronics</td><td>45.91</td><td>1</td><td>45.91</td></tr><tr><td>2023-01-01</td><td>20230101-547596</td><td>7266</td><td>Home</td><td>43.17</td><td>3</td><td>129.51</td></tr><tr><td>2023-01-01</td><td>20230101-787805</td><td>9721</td><td>Toys</td><td>12.23</td><td>1</td><td>12.23</td></tr><tr><td>2023-01-01</td><td>20230101-827793</td><td>6212</td><td>Electronics</td><td>262.72</td><td>1</td><td>262.72</td></tr><tr><td>2023-01-01</td><td>20230101-781738</td><td>4741</td><td>Electronics</td><td>168.44</td><td>3</td><td>505.32</td></tr><tr><td>2023-01-01</td><td>20230101-365277</td><td>1205</td><td>Grocery</td><td>12.18</td><td>2</td><td>24.36</td></tr><tr><td>2023-01-01</td><td>20230101-958394</td><td>3983</td><td>Beauty</td><td>50.45</td><td>1</td><td>50.45</td></tr><tr><td>2023-01-01</td><td>20230101-699389</td><td>7049</td><td>Home</td><td>89.97</td><td>1</td><td>89.97</td></tr><tr><td>2023-01-01</td><td>20230101-227135</td><td>5993</td><td>Home</td><td>98.91</td><td>2</td><td>197.82</td></tr><tr><td>2023-01-01</td><td>20230101-579840</td><td>1404</td><td>Home</td><td>108.08</td><td>2</td><td>216.16</td></tr><tr><td>2023-01-01</td><td>20230101-469197</td><td>4362</td><td>Electronics</td><td>210.75</td><td>1</td><td>210.75</td></tr><tr><td>2023-01-01</td><td>20230101-772064</td><td>2613</td><td>Beauty</td><td>22.07</td><td>1</td><td>22.07</td></tr><tr><td>2023-01-01</td><td>20230101-940934</td><td>1125</td><td>Electronics</td><td>74.27</td><td>1</td><td>74.27</td></tr><tr><td>2023-01-01</td><td>20230101-122591</td><td>7437</td><td>Toys</td><td>34.82</td><td>4</td><td>139.28</td></tr><tr><td>2023-01-01</td><td>20230101-637241</td><td>5996</td><td>Beauty</td><td>22.44</td><td>3</td><td>67.32</td></tr><tr><td>2023-01-01</td><td>20230101-697204</td><td>1982</td><td>Toys</td><td>50.45</td><td>1</td><td>50.45</td></tr><tr><td>2023-01-01</td><td>20230101-933824</td><td>4832</td><td>Beauty</td><td>16.77</td><td>1</td><td>16.77</td></tr><tr><td>2023-01-01</td><td>20230101-893468</td><td>1598</td><td>Beauty</td><td>22.07</td><td>1</td><td>22.07</td></tr><tr><td>2023-01-01</td><td>20230101-510091</td><td>2039</td><td>Electronics</td><td>54.4</td><td>1</td><td>54.4</td></tr><tr><td>2023-01-01</td><td>20230101-762411</td><td>8874</td><td>Grocery</td><td>17.57</td><td>1</td><td>17.57</td></tr><tr><td>2023-01-01</td><td>20230101-106368</td><td>4362</td><td>Beauty</td><td>7.07</td><td>6</td><td>42.42</td></tr><tr><td>2023-01-01</td><td>20230101-843448</td><td>5824</td><td>Beauty</td><td>26.18</td><td>2</td><td>52.36</td></tr><tr><td>2023-01-01</td><td>20230101-404412</td><td>4307</td><td>Home</td><td>41.39</td><td>1</td><td>41.39</td></tr><tr><td>2023-01-01</td><td>20230101-514446</td><td>5818</td><td>Grocery</td><td>8.42</td><td>1</td><td>8.42</td></tr><tr><td>2023-01-01</td><td>20230101-552973</td><td>8745 ...

# %%
# Clear old widgets (safe practice)
dbutils.widgets.removeAll()

# Create widgets
dbutils.widgets.text(
    "bronze_table",
    "main.default.bronze_sales"
)

dbutils.widgets.text(
    "silver_table",
    "main.default.silver_sales"
)

# Read widget values
bronze_table = dbutils.widgets.get("bronze_table")
silver_table = dbutils.widgets.get("silver_table")

# Read data from Bronze
df = spark.read.table(bronze_table)

# ---- Silver Transformations ----
# 1. Remove duplicates
# 2. Remove nulls
df_clean = df.dropDuplicates().dropna()

# Write to Silver table
df_clean.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable(silver_table)

print("✅ Silver layer completed:", silver_table)
# Out:
# ✅ Silver layer completed: main.default.silver_sales

# %%
# %sql
SELECT COUNT(*) FROM main.default.silver_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>129675</td></tr></tbody></table></div>

# %%
# Clear widgets (best practice)
dbutils.widgets.removeAll()

# Create widgets
dbutils.widgets.text(
    "silver_table",
    "main.default.silver_sales"
)

dbutils.widgets.text(
    "gold_table",
    "main.default.gold_sales"
)

# Read widget values
silver_table = dbutils.widgets.get("silver_table")
gold_table = dbutils.widgets.get("gold_table")

# Read Silver data
df = spark.read.table(silver_table)

# ---- Gold Transformations ----
# Example business logic:
# Total records per category
df_gold = df.groupBy("category").count()

# Write to Gold table
df_gold.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable(gold_table)

print("✅ Gold layer completed:", gold_table)
# Out:
# ✅ Gold layer completed: main.default.gold_sales

# %%
# %sql
SELECT * FROM main.default.gold_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>count</th></tr></thead><tbody><tr><td>Toys</td><td>20881</td></tr><tr><td>Home</td><td>28576</td></tr><tr><td>Beauty</td><td>23232</td></tr><tr><td>Grocery</td><td>20765</td></tr><tr><td>Electronics</td><td>36221</td></tr></tbody></table></div>
